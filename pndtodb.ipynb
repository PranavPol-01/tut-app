# %%
import pandas as pd
import sqlite3

df=pd.read_excel('.\sports.xlsx')
conn = sqlite3.connect('sport.db')
df.to_sql('sport', conn, if_exists='replace', index=False)
df
# Out:
#                        Children (Ages 0-12) Teenagers (Ages 13-19)  \
# 0                           Soccer/Football        Soccer/Football
# 1                                Basketball             Basketball
# 2                                  Swimming             Volleyball
# 3                                Gymnastics        Track and Field
# 4                                    Tennis               Swimming
# 5  Martial Arts (such as Taekwondo, Karate)                 Tennis
# 6                         Baseball/Softball          Skateboarding
# 7                                 Badminton              Badminton
# 8                                       NaN         Esports/Gaming
#
#   Young Adults (Ages 20-39)         Middle-Aged Adults (Ages 40-59)  \
# 0           Soccer/Football                         Running/Jogging
# 1                Basketball                                 Cycling
# 2           Running/Jogging                                    Golf
# 3                    Tennis                                  Tennis
# 4              Gym Workouts                                Swimming
# 5                      Yoga                                  Hiking
# 6                   Cycling                                    Yoga
# 7                 Badminton                       Softball/Baseball
# 8             Rock Climbing  Soccer/Football (recreational leagues)
#
#   Older Adults (Ages 60+)
# 0                 Walking
# 1                    Golf
# 2                Swimming
# 3                 Cycling
# 4                 Tai Chi
# 5                    Yoga
# 6                 Bowling
# 7                Aerobics
# 8          Petanque/Bocce
